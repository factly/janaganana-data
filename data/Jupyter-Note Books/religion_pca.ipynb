# %%
import pandas as pd
df = pd.read_csv('D:/religion_pca.csv', low_memory=False)

# %%
df.head(5)
# Out:
#   State District Subdistt Town/Village    TRU   Name   Religion       TOT_P  \
# 0    00      000    00000       000000  Total  INDIA      Total  1210854977
# 1    00      000    00000       000000  Total  INDIA      Hindu   966257353
# 2    00      000    00000       000000  Total  INDIA     Muslim   172245158
# 3    00      000    00000       000000  Total  INDIA  Christian    27819588
# 4    00      000    00000       000000  Total  INDIA       Sikh    20833116
#
#        TOT_M      TOT_F    ...     MARG_AL_0_3_F MARG_HH_0_3_P MARG_HH_0_3_M  \
# 0  623270258  587584719    ...           5820403       1420348        491424
# 1  498306968  467950385    ...           4990261       1052248        374549
# 2   88273945   83971213    ...            503064        300836         94229
# 3   13751031   14068557    ...             94337         26977          9353
# 4   10948431    9884685    ...             59022         15417          5551
#
# ...

# %%
len(df)
# Out:
# 400418

# %%
rs=df[df.State!='State']

# %%
len(rs)
# Out:
# 400383

# %%
rs['Name']=rs['Name'].str.lower()
# Out:
# C:\Users\mthipparthi\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
rs.head(5)
# Out:
#   State District Subdistt Town/Village    TRU   Name   Religion       TOT_P  \
# 0    00      000    00000       000000  Total  india      Total  1210854977
# 1    00      000    00000       000000  Total  india      Hindu   966257353
# 2    00      000    00000       000000  Total  india     Muslim   172245158
# 3    00      000    00000       000000  Total  india  Christian    27819588
# 4    00      000    00000       000000  Total  india       Sikh    20833116
#
#        TOT_M      TOT_F    ...     MARG_AL_0_3_F MARG_HH_0_3_P MARG_HH_0_3_M  \
# 0  623270258  587584719    ...           5820403       1420348        491424
# 1  498306968  467950385    ...           4990261       1052248        374549
# 2   88273945   83971213    ...            503064        300836         94229
# 3   13751031   14068557    ...             94337         26977          9353
# 4   10948431    9884685    ...             59022         15417          5551
#
# ...

# %%
result = rs[ (rs.Name == 'india') | (rs.Name.str.startswith('district')) | (rs.Name.str.startswith('state'))]

# %%
result.head(5)
# Out:
#   State District Subdistt Town/Village    TRU   Name   Religion       TOT_P  \
# 0    00      000    00000       000000  Total  india      Total  1210854977
# 1    00      000    00000       000000  Total  india      Hindu   966257353
# 2    00      000    00000       000000  Total  india     Muslim   172245158
# 3    00      000    00000       000000  Total  india  Christian    27819588
# 4    00      000    00000       000000  Total  india       Sikh    20833116
#
#        TOT_M      TOT_F    ...     MARG_AL_0_3_F MARG_HH_0_3_P MARG_HH_0_3_M  \
# 0  623270258  587584719    ...           5820403       1420348        491424
# 1  498306968  467950385    ...           4990261       1052248        374549
# 2   88273945   83971213    ...            503064        300836         94229
# 3   13751031   14068557    ...             94337         26977          9353
# 4   10948431    9884685    ...             59022         15417          5551
#
# ...

# %%
len(result)
# Out:
# 19197

# %%
result.to_csv('D:/religion_pca_cleaned.csv')
